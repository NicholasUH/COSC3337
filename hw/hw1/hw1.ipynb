# %% [markdown]
# # Part 1. Reading and Understanding the Data

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams

# %%
rcParams['figure.figsize'] = 8, 5
sns.set_style('darkgrid')

# %%
cars_df = pd.read_csv(filepath_or_buffer='car_data.csv')
cars_df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
cars_df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
cars_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %% [markdown]
# # Part 2. Data Cleaning and Preparation

# %%
cars_df['car_company'] = cars_df['CarName'].apply(lambda x: x.split()[0].lower())

unique_companies = cars_df['car_company'].unique()
print(unique_companies)
# Out:
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'maxda' 'mazda' 'buick' 'mercury' 'mitsubishi' 'nissan' 'peugeot'
#  'plymouth' 'porsche' 'porcshce' 'renault' 'saab' 'subaru' 'toyota'
#  'toyouta' 'vokswagen' 'volkswagen' 'vw' 'volvo']

# %%
cars_df['car_company'] = cars_df['car_company'].replace('toyouta', 'toyota')
cars_df['car_company'] = cars_df['car_company'].replace('porcshce', 'porsche')
cars_df['car_company'] = cars_df['car_company'].replace('maxda', 'mazda')
cars_df['car_company'] = cars_df['car_company'].replace('vokswagen', 'volkswagen')
cars_df['car_company'] = cars_df['car_company'].replace('vw', 'Volkswagen')

print(unique_companies)
# Out:
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'maxda' 'mazda' 'buick' 'mercury' 'mitsubishi' 'nissan' 'peugeot'
#  'plymouth' 'porsche' 'porcshce' 'renault' 'saab' 'subaru' 'toyota'
#  'toyouta' 'vokswagen' 'volkswagen' 'vw' 'volvo']

# %% [markdown]
# # Part 3. Visualising Categorical Data

# %%
'''
A plot of the unique company names on the x-axis, and the value counts on the y-axis.
A plot of the unique car bodys on the x-axis and value counts on the y-axis.
'''

plt.figure(figsize=(4, 3))
cars_df['car_company'].value_counts().plot(kind='bar')
plt.xlabel('CompanyName')
plt.ylabel('Count')
plt.title('Company Counts')
plt.show()

plt.figure(figsize=(4, 3))
cars_df['carbody'].value_counts().plot(kind='bar')
plt.ylabel('count')
plt.title('Car Body Counts')
plt.show()

# %% [markdown]
# **From these two plots, we are able to see the distribution and count of each unique company and unique car body .
# Here we can see that Toyota has a signicantly higher count than the other companies. From the Car Body Count graph, we see that sedan and hunchback take up a significant portion of the overall count.**

# %%
'''
A plot of the unique company names on the x-axis, and that companies average price on the y-axis.
A plot of the unique car bodys on the x-axis and that car body's average price on the y-axis.
'''

plt.figure(figsize=(5, 3))
sns.barplot(data=cars_df, x='car_company', y='price')
plt.xlabel('Company Names')
plt.ylabel('count')
plt.title('Company v. Average Price')
plt.xticks(rotation=90)
plt.show()

plt.figure(figsize=(5, 3))
sns.barplot(data=cars_df, x='carbody', y='price')
plt.xlabel('Car Bodies')
plt.ylabel('price')
plt.title('Car Body v. Average Price')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **From the Company v. Price plot, we can conclude that companies mazda, buick, porshce, and bmw have significantly higher average prices compared to the other companies. In the Car Body v. Price graph, convertible and hardtop, have higher average prices compared to hatchback, sedan, and wagon.**

# %%
'''
A plot of the unique symboling values on the x-axis, and the value counts on the y-axis.
A box plot of the unique symboling values on the x-axis and price on the y-axis.
'''

plt.figure(figsize=(4, 3))
sns.countplot(data=cars_df, x='symboling')
plt.xlabel('symboling')
plt.ylabel('count')
plt.title('Symboling Counts')
plt.show()

plt.figure(figsize=(4, 3))
sns.boxplot(data=cars_df, x='symboling', y='price')
plt.xlabel('symboling')
plt.ylabel('price')
plt.title('Symboling v. Price')
plt.show()

# %% [markdown]
# **From the symboling count graph, we see that most of the values fall on 0 or 1, meaning most of the cars in the dataset will be neutral or slightly risky. In the boxplot, we can see that cars with symboling below 0 have higher median values than those with positive symboling values indicating that the safety of a car does play a role in the price of a car.**

# %%
'''
A plot of enginetype on the x-axis, and the value counts on the y-axis.
A box plot of enginetype on the x-axis and price on the y-axis.
'''

plt.figure(figsize=(4, 3))
sns.countplot(data=cars_df, x='enginetype')
plt.xlabel('engine')
plt.ylabel('count')
plt.title('Engine Counts')
plt.show()

plt.figure(figsize=(4, 3))
sns.boxplot(data=cars_df, x='enginetype', y='price')
plt.xlabel('engine')
plt.ylabel('price')
plt.title('engine v. Price')
plt.show()

# %% [markdown]
# **From the enginetype count graph, we conclude that a large majority of the enginetype of the observations of the dataset will be 'ohc' with over 140 counts. From the boxplot, we can see that ohcv has a very large range of values indicated by the two ends representing the minimum and maximum values, while dohc, rotor, ohcf, dohcv, and I engine have lower ranges.**

# %%
'''
A plot of cylindernumber on the x-axis, and the value counts on the y-axis.
A box plot of cylindernumber on the x-axis and price on the y-axis.
'''

plt.figure(figsize=(4, 3))
sns.countplot(data=cars_df, x='cylindernumber')
plt.xlabel('cylinder')
plt.ylabel('count')
plt.title('Cylinder Count')
plt.show()

plt.figure(figsize=(4, 3))
sns.boxplot(data=cars_df, x='cylindernumber', y='price')
plt.xlabel('cylinder')
plt.ylabel('price')
plt.title('Cylinder v. Price')
plt.show()

# %% [markdown]
# **From the count graph, it seems a majority of cars have 4 cylinders amounting to above 150. According to the cylinder v. price graph, three and twelve cylinders seem to have no spread in values, while six has the largest spread.**

# %%
'''
A plot of fuelsystem on the x-axis, and the value counts on the y-axis.
A box plot of fuelsystem on the x-axis and price on the y-axis.
'''

plt.figure(figsize=(4, 3))
sns.countplot(data=cars_df, x='fuelsystem')
plt.xlabel('fuelsystem')
plt.ylabel('count')
plt.title('fuelsystem Count')
plt.show()

plt.figure(figsize=(4, 3))
sns.boxplot(data=cars_df, x='fuelsystem', y='price')
plt.xlabel('fuelsystem')
plt.ylabel('price')
plt.title('fuelsystem v. Price')
plt.show()

# %% [markdown]
# **We can conclude that the fuel system that appears the most is mpfi and 2bbl. From the boxplot, we can see that mfi and spfi has no range, while idi has the largest range.**

# %%
'''
A plot of drivewheel on the x-axis, and the value counts on the y-axis.
A box plot of drivewheel on the x-axis and price on the y-axis.
'''

plt.figure(figsize=(4, 3))
sns.countplot(data=cars_df, x='drivewheel')
plt.xlabel('drivewheel')
plt.ylabel('count')
plt.title('drivewheel Count')
plt.show()

plt.figure(figsize=(4, 3))
sns.boxplot(data=cars_df, x='drivewheel', y='price')
plt.xlabel('drivewheel')
plt.ylabel('price')
plt.title('drivewheel v. Price')
plt.show()

# %% [markdown]
# **From the count graph, we see that most of the observations have rwd and fwd drivewheel while very little have 4wd. From the boxplot, we see that rwd has a very large range and the highest median value comparead to the other two fwd and 4wd.**

# %%
'''
A plot of enginelocation on the x-axis, and the value counts on the y-axis.
A box plot of enginelocation on the x-axis and price on the y-axis.
'''

plt.figure(figsize=(4, 3))
sns.countplot(data=cars_df, x='enginelocation')
plt.xlabel('enginelocation')
plt.ylabel('count')
plt.title('enginelocation Count')
plt.show()

plt.figure(figsize=(4, 3))
sns.boxplot(data=cars_df, x='enginelocation', y='price')
plt.xlabel('enginelocation')
plt.ylabel('price')
plt.title('enginelocation v. Price')
plt.show()

# %% [markdown]
# **From the count graph, we see that most engines are located in the front rather than in the back. From the boxplot, we conclude that front engine location has a larger spread than back engine location, but back has a higher price overall.**

# %%
'''
A plot of fueltype on the x-axis, and the value counts on the y-axis.
A box plot of fueltype on the x-axis and price on the y-axis.
'''

plt.figure(figsize=(4, 3))
sns.countplot(data=cars_df, x='fueltype')
plt.xlabel('fueltype')
plt.ylabel('count')
plt.title('fueltype Count')
plt.show()

plt.figure(figsize=(4, 3))
sns.boxplot(data=cars_df, x='fueltype', y='price')
plt.xlabel('fueltype')
plt.ylabel('price')
plt.title('fueltype v. Price')
plt.show()

# %% [markdown]
# **It seems from the count graph, that a majority of the vehicles are gas rather than diesel. From the box plot, it seems that diesel has a higher median value than gas meaning that in general, diesel vehicles are more expensive than gas vehicles.**

# %%
'''
A plot of doornumber on the x-axis, and the value counts on the y-axis.
A box plot of doornumber on the x-axis and price on the y-axis.
'''

plt.figure(figsize=(4, 3))
sns.countplot(data=cars_df, x='doornumber')
plt.xlabel('doornumber')
plt.ylabel('count')
plt.title('doornumber Count')
plt.show()

plt.figure(figsize=(4, 3))
sns.boxplot(data=cars_df, x='doornumber', y='price')
plt.xlabel('doornumber')
plt.ylabel('price')
plt.title('doornumber v. Price')
plt.show()

# %% [markdown]
# **From the count graph, we see that more cars have four doors rather than two, but not that much of a difference. The boxplots between two and four doors are almost identical, but four door has a slightly higher median price value.**

# %%
'''
A plot of aspiration on the x-axis, and the value counts on the y-axis.
A box plot of aspiration on the x-axis and price on the y-axis.
'''

plt.figure(figsize=(4, 3))
sns.countplot(data=cars_df, x='aspiration')
plt.xlabel('aspiration')
plt.ylabel('count')
plt.title('aspiration Count')
plt.show()

plt.figure(figsize=(4, 3))
sns.boxplot(data=cars_df, x='aspiration', y='price')
plt.xlabel('aspiration')
plt.ylabel('price')
plt.title('aspiration v. Price')
plt.show()

# %% [markdown]
# **We see from the count graph that a majority of observations fall in the std category. From the box plot, we can conclude that the vehicles with turbo has a higher median value meaning that they are overall more expensive than the the vehicles with std.**

# %% [markdown]
# # Part 4. Visualising Numerical Data

# %%
plt.figure(figsize=(5, 5))
sns.distplot(cars_df['price'], kde=True)
plt.xlabel('price')
plt.title('Car Price Distribution')
plt.show()

plt.figure(figsize=(5,5))
sns.boxplot(data=cars_df, x='price')
plt.xlabel('price')
plt.title('Car Price Spread')
plt.show()
# Out:
# /var/folders/wm/jx340d6s0lb590f_mwhfwhxr0000gn/T/ipykernel_57003/3529467978.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars_df['price'], kde=True)

# %% [markdown]
# **From the distribution plot, we see that the graph is skewed right. While from the box plot, we can conclude that the spraed goes from 5000 to about 28000**

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 10))  

sns.regplot(x=cars_df['carlength'], y=cars_df['price'], ax=axs[0, 0])
axs[0, 0].set_xlabel('Car Length')
axs[0, 0].set_ylabel('Price')
axs[0, 0].set_title('Car Length v. Price')

sns.regplot(x=cars_df['carwidth'], y=cars_df['price'], ax=axs[0, 1])
axs[0, 1].set_xlabel('Car Width')
axs[0, 1].set_ylabel('Price')
axs[0, 1].set_title('Car Width v. Price')

sns.regplot(x=cars_df['carheight'], y=cars_df['price'], ax=axs[1, 0])
axs[1, 0].set_xlabel('Car Height')
axs[1, 0].set_ylabel('Price')
axs[1, 0].set_title('Car Height v. Price')

sns.regplot(x=cars_df['curbweight'], y=cars_df['price'], ax=axs[1, 1])
axs[1, 1].set_xlabel('Curb Weight')
axs[1, 1].set_ylabel('Price')
axs[1, 1].set_title('Curb Weight v. Price')

plt.tight_layout()
plt.show()

# %% [markdown]
# **All the graphs seem to have a strong positive linear relationship. The line fitting to the data points well suggests that the linear model represents a good relationship between price and the features.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have already loaded your dataframe `cars_df`

fig, axs = plt.subplots(3, 3, figsize=(15, 15))  # Creating a 3x3 grid of subplots

sns.regplot(x=cars_df['enginesize'], y=cars_df['price'], ax=axs[0, 0])
axs[0, 0].set_xlabel('Engine Size')
axs[0, 0].set_ylabel('Price')
axs[0, 0].set_title('Engine Size v. Price')

sns.regplot(x=cars_df['boreratio'], y=cars_df['price'], ax=axs[0, 1])
axs[0, 1].set_xlabel('Bore Ratio')
axs[0, 1].set_ylabel('Price')
axs[0, 1].set_title('Bore Ratio v. Price')

sns.regplot(x=cars_df['stroke'], y=cars_df['price'], ax=axs[0, 2])
axs[0, 2].set_xlabel('Stroke')
axs[0, 2].set_ylabel('Price')
axs[0, 2].set_title('Stroke v. Price')

sns.regplot(x=cars_df['compressionratio'], y=cars_df['price'], ax=axs[1, 0])
axs[1, 0].set_xlabel('Compression Ratio')
axs[1, 0].set_ylabel('Price')
axs[1, 0].set_title('Compression Ratio v. Price')

sns.regplot(x=cars_df['horsepower'], y=cars_df['price'], ax=axs[1, 1])
axs[1, 1].set_xlabel('Horsepower')
axs[1, 1].set_ylabel('Price')
axs[1, 1].set_title('Horsepower v. Price')

sns.regplot(x=cars_df['peakrpm'], y=cars_df['price'], ax=axs[1, 2])
axs[1, 2].set_xlabel('Peak RPM')
axs[1, 2].set_ylabel('Price')
axs[1, 2].set_title('Peak RPM v. Price')

sns.regplot(x=cars_df['wheelbase'], y=cars_df['price'], ax=axs[2, 0])
axs[2, 0].set_xlabel('Wheelbase')
axs[2, 0].set_ylabel('Price')
axs[2, 0].set_title('Wheelbase v. Price')

sns.regplot(x=cars_df['citympg'], y=cars_df['price'], ax=axs[2, 1])
axs[2, 1].set_xlabel('City MPG')
axs[2, 1].set_ylabel('Price')
axs[2, 1].set_title('City MPG v. Price')

sns.regplot(x=cars_df['highwaympg'], y=cars_df['price'], ax=axs[2, 2])
axs[2, 2].set_xlabel('Highway MPG')
axs[2, 2].set_ylabel('Price')
axs[2, 2].set_title('Highway MPG v. Price')

plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

# %% [markdown]
# The graphs for compression ratio, peak RPM and Stroke show no or bad correlation with the price variable. Graphs for engine size,bore ratio, horsepower, and wheelbase show a strong positive relationship with price, while highway MPG and city MPG show a negative correlation.

# %%
correlation_matrix = cars_df.corr(numeric_only = True)

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='YlGnBu', fmt=".2f")
plt.show()

# %% [markdown]
# From the heatmap, the features I see that we could combine are highway and city MPG cause the correlation coefficient is .97. We could also try to combine those with absolute correlation coeffiecients higher than .85 like curbweight and carwidth or curbweight and carlength.

# %%
cars_df['fuel_economy'] = ((cars_df['citympg'] * .55) + (cars_df['highwaympg'] * .45))
cars_df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  boreratio  stroke  \
# 0  convertible        rwd          front       88.6  ...       3.47    2.68
# 1  convertible        rwd          front       88.6  ...       3.47    2.68
# 2    hatchback        rwd          front       94.5  ...       2.68    3.47
# 3        sedan        fwd          front       99.8  ...       3.19    3.40
# 4        sedan        4wd          front       99.4  ...       3.19    3.40
#
# ...

# %% [markdown]
# According to the heatmap and correlation matrix, we can conclude that the best variables at predicting price are curbweight, engine size, and horsepower because of the correlation coefficients being .84, .87, and .81 respectively.

# %% [markdown]
# # Part 5. Data Pre-Processing

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

categorical_variables = ['symboling', 'fueltype', 'enginetype', 'carbody', 'doornumber', 'enginelocation'
                        ,'fuelsystem', 'cylindernumber', 'aspiration', 'drivewheel']

dummy_cars_df = pd.get_dummies(cars_df, columns=categorical_variables)


to_be_scaled = [x for x in dummy_cars_df.columns if x not in ['car_ID', 'CarName', 'car_company']]

scaled_data = StandardScaler().fit_transform(dummy_cars_df[to_be_scaled])

scaled_cars_df = pd.DataFrame(scaled_data, columns = to_be_scaled)

y = scaled_cars_df['price']
X = scaled_cars_df.drop(columns = ['price'])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=2024)

# %% [markdown]
# # Part 6. Model Creation and Evaluation

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score


model = LinearRegression()
model.fit(X_train, y_train)

predictions = model.predict(X_test)

plt.scatter(y_test, predictions)
plt.xlabel('True y')
plt.ylabel('Prediction')
plt.title('True y v. Prediction')
plt.show()

residuals = y_test - predictions

sns.histplot(residuals, bins=20, kde = True)
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.title('Histogram of Residuals')
plt.show()

r2 = r2_score(y_test, predictions)
print("R^2 score:", r2)
# Out:
# R^2 score: 0.8445788218986414

# %% [markdown]
# **85% of the variance can be explained by the model**

# %%
coefficients = pd.DataFrame(model.coef_)
variables = pd.DataFrame(X.columns, columns=['Variable'])

result = pd.concat([variables, coefficients], axis=1)

display(result)
# Out:
#                  Variable             0
# 0               wheelbase  5.914339e-03
# 1               carlength -7.825334e-02
# 2                carwidth  1.603103e-01
# 3               carheight  6.121231e-02
# 4              curbweight  2.815336e-01
# 5              enginesize  8.111782e-01
# 6               boreratio -2.015949e-01
# 7                  stroke -2.312245e-01
# 8        compressionratio -5.002106e-02
# 9              horsepower  9.538287e-02
# 10                peakrpm  1.313510e-01
# 11                citympg -2.213844e-01
# 12             highwaympg  1.970871e-01
# 13           fuel_economy -2.794742e-02
# 14           symboling_-2 -7.730764e-02
# 15           symboling_-1 -1.420113e-02
# 16            symboling_0  2.617421e-02
# 17            symboling_1  2.298531e-02
# 18            symboling_2 -2.448296e-02
# 19            symboling_3  4.821415e-04
# 20        fueltype_diesel  4.607786e-02
# 21           fueltype_gas -4.607786e-02
# ...

# %% [markdown]
# **From the coefficients, we can see the relationship between each feature and the price. If positive, we can see their is a positive linear relationship, if negative, its a negative linear relationship. We can also see the strength of each relationship based on the value.**
